# %%
try:
    b= open("data.csv",'x')
    b.close()
except:
    print("File already exist")

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.") #dataframe- pandas datatype
df
# Out:
#         Name  Age    Address       Phone
# S.N.
# 1        Ram   45  kathmandu  9843235201
# 2      Shyam   32    pokhara  9834320110
# 3       Hari   54       Bara  9860438451
# 4      Rabin   23  Bharatpur  9803803868
# 5        Rob   43   Lalitpur  9824150102
# 6     Nikesh   34       Rara  9843205205

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df.head() #reads first 5 values from top by default
# Out:
#        Name  Age    Address       Phone
# S.N.
# 1       Ram   45  kathmandu  9843235201
# 2     Shyam   32    pokhara  9834320110
# 3      Hari   54       Bara  9860438451
# 4     Rabin   23  Bharatpur  9803803868
# 5       Rob   43   Lalitpur  9824150102

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df.tail() #reads 5 data from bottom by default
# Out:
#         Name  Age    Address       Phone
# S.N.
# 2      Shyam   32    pokhara  9834320110
# 3       Hari   54       Bara  9860438451
# 4      Rabin   23  Bharatpur  9803803868
# 5        Rob   43   Lalitpur  9824150102
# 6     Nikesh   34       Rara  9843205205

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df.tail(6)
# Out:
#         Name  Age    Address       Phone
# S.N.
# 1        Ram   45  kathmandu  9843235201
# 2      Shyam   32    pokhara  9834320110
# 3       Hari   54       Bara  9860438451
# 4      Rabin   23  Bharatpur  9803803868
# 5        Rob   43   Lalitpur  9824150102
# 6     Nikesh   34       Rara  9843205205

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.",usecols=['S.N.','Name','Phone']) #to only display sn,name and phone
df
# Out:
#         Name       Phone
# S.N.
# 1        Ram  9843235201
# 2      Shyam  9834320110
# 3       Hari  9860438451
# 4      Rabin  9803803868
# 5        Rob  9824150102
# 6     Nikesh  9843205205

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df.iloc[1:4] #index (prints from 1-4)// by default it starts from 0
# Out:
#        Name  Age    Address       Phone
# S.N.
# 2     Shyam   32    pokhara  9834320110
# 3      Hari   54       Bara  9860438451
# 4     Rabin   23  Bharatpur  9803803868

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df.loc[1:4] # values
# Out:
#        Name  Age    Address       Phone
# S.N.
# 1       Ram   45  kathmandu  9843235201
# 2     Shyam   32    pokhara  9834320110
# 3      Hari   54       Bara  9860438451
# 4     Rabin   23  Bharatpur  9803803868

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="Name")
df.loc['Ram':'Rabin']
# Out:
#        S.N.  Age    Address       Phone
# Name
# Ram       1   45  kathmandu  9843235201
# Shyam     2   32    pokhara  9834320110
# Hari      3   54       Bara  9860438451
# Rabin     4   23  Bharatpur  9803803868

# %%
#condition age limit

import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df['Age']
# Out:
# S.N.
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Age, dtype: bool

# %%
#condition age limit

import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df['Age']>40
# Out:
# S.N.
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Age, dtype: bool

# %%
#condition age limit

import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df[df['Age']>40]
# Out:
#       Name  Age    Address       Phone
# S.N.
# 1      Ram   45  kathmandu  9843235201
# 3     Hari   54       Bara  9860438451
# 5      Rob   43   Lalitpur  9824150102

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
df[df['Address']== 'kathmandu']
# Out:
#      Name  Age    Address       Phone
# S.N.
# 1     Ram   45  kathmandu  9843235201

# %%
import pandas as pd #package
df= pd.read_csv('data.csv',index_col="S.N.")
data=df[df['Age']>40]
data.to_csv('new_data.csv')

# %%
import pandas as pd
df= pd.read_csv('new_data.csv',index_col='S.N.')
df
# Out:
#       Name  Age    Address       Phone
# S.N.
# 1      Ram   45  kathmandu  9843235201
# 3     Hari   54       Bara  9860438451
# 5      Rob   43   Lalitpur  9824150102

# %%
#list inside dict
import pandas as pd
d= {'Name':['ram','shyam','hari'], 
    'age':[23,45,32],
    'address': ['kathmandu', 'bhaktapur', 'lalitpur']}

df= pd.DataFrame(d)
df
# Out:
#     Name  age    address
# 0    ram   23  kathmandu
# 1  shyam   45  bhaktapur
# 2   hari   32   lalitpur

# %%
#json format(used in django)

import pandas as pd
d= {'Name':['ram','shyam','hari'], 
    'age':[23,45,32],
    'address': ['kathmandu', 'bhaktapur', 'lalitpur']}

df= pd.DataFrame(d)
df.to_json('new_data.json')

# %%
#to csv
import pandas as pd
d= {'Name':['ram','shyam','hari'], 
    'age':[23,45,32],
    'address': ['kathmandu', 'bhaktapur', 'lalitpur']}

df= pd.DataFrame(d)
df.to_csv('datas.csv')

# %%
#WAP to enter list inside list data into csv

import pandas as pd

l=[['name',['ram','hari','ram']],['age',[23,43,54]]]

df=pd.DataFrame(l)
df.to_csv('lists.csv')
