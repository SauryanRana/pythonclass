# %%
#function
# def <function_name>():
#   <operations>


#<funtion_name()

# %%
def hello():
    print("hello world")
    
hello()
# Out:
# hello world

# %%
def cal():
    l=10
    b=4
    h=2
    v=l*b*h
    print(v)
    
cal()
# Out:
# 80

# %%
def cal():
    l=int(input("enter length- ")) #local variable-can only be called within this function & not be used outside this function
    b=int(input("enter breadth- ")) #local variable
    h=int(input("enter height- ")) #local variable
    v=l*b*h
    print(v)
    
cal()
# Out:
# enter length- 4
# enter breadth- 3
# enter height- 2
# 24

# %%
def hello():
    x=input("enter x= ")
    y=input("enter y= ")
    print(x+" "+y)
    
hello()
# Out:
# enter x= hello
# enter y= world
# hello world

# %%
l=int(input("enter length- ")) #local variable-can only be called within this function & not be used outside this function
b=int(input("enter breadth- ")) #local variable
h=int(input("enter height- ")) #local variable

def cal():
    v=l*b*h
    print(v)
    
cal()
print(l,b,h)
# Out:
# enter length- 10
# enter breadth- 20
# enter height- 3
# 600
# 10 20 3

# %%
def cal():
    global l,b,h #defining the variables globally; can be called outside this function as well
    l=int(input("enter length- ")) 
    b=int(input("enter breadth- ")) 
    h=int(input("enter height- ")) 
    v=l*b*h
    print(v)
    
cal()
print(l,b,h)
# Out:
# enter length- 10
# enter breadth- 2
# enter height- 3
# 60
# 10 2 3

# %%
#argument, return type

# %%
# function with argument but no return type

def area(l,b): #argument and parameter
    a=l*b
    print(a)

area(10,5)
# Out:
# 50

# %%
def cal(x,y,z): #parameter
    v=x*y*z
    print(v)

l=int(input("enter length- ")) 
b=int(input("enter breadth- ")) 
h=int(input("enter height- ")) 

cal(l,b,h) #argument
# Out:
# enter length- 10
# enter breadth- 2
# enter height- 4
# 80

# %%
def language(lan= "python"):
    print(lan)
    
language("C++")
language("C")
language("Java")  #arugument gets main priority than parameters
language()
# Out:
# C++
# C
# Java
# python

# %%
def language(name, lan="python"):
    print(name, lan)
    
language("ram","C++")
language("hari","C")
language("shiva","Java")  #arugument gets more priority than parameters
language("Nabin")
# Out:
# ram C++
# hari C
# shiva Java
# Nabin python

# %%
#return type function
def cal():
    l=10
    b=5
    a=l*b
    return a

print(cal())
# Out:
# 50

# %%
def cal():
    l=10
    b=5
    h=2
    a=l*b
    v=a*h
    return a,v

x=cal()
print(x)
# Out:
# (50, 100)

# %%
#to print both area and volume differently
def cal():
    l=10
    b=5
    h=2
    a=l*b
    v=a*h
    return a,v

x=cal()
area,volume=x
print(area)
print(volume)
# Out:
# 50
# 100

# %%
def info(name,age,add):
    s= "hello my me is " + name +" I am from "+add + " i am "+ str(age)
    return s

name=input("enter name")
age= int(input("enter age"))
add= input("enter address")


x=info(name,age,add)
print(x)
# Out:
# enter nameram
# enter age34
# enter addressnepal
# hello my me is ram I am from nepal i am 34

# %%
def area(l,b):
    a=l*b
    return a

def volume(l,b,h):
    v= area(l,b)*h
    return v

l= int(input("enter length- "))
b= int(input("enter breadth- "))
h= int(input("enter height- "))

print(volume(l,b,h))
# Out:
# enter length- 4
# enter breadth- 3
# enter height- 2
# 24

# %%
def add(a,b):
    return a+b

def sub(a,b):
    return a-b

def mult(a,b):
    return a*b

def div(a,b):
    return a/b

def cal():
    a= int(input("enter the value of a "))
    b= int(input("enter the value of b "))
    o=input("enter +, -, *, /")

    if o== "+":
        print(add(a,b))
    elif o== "-":
        print(sub(a,b))
    elif o== "*":
        print(mult(a,b))
    elif o== "/":
        orint(div(a,b))
    else:
        print("invalid operator")
        
cal()
# Out:
# enter the value of a 5
# enter the value of b 6
# enter +, -, *, /*
# 30

# %%
def hello():
    print("hello world")
    hello() #if we define this within the function, it runs in loop
    
hello()
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
def hello():
    print("hello world")
    x= input("enter y for more calculation- ")
    if x == 'y':
        hello()
        
hello()
# Out:
# hello world
# enter y for more calculation- y
# hello world
# enter y for more calculation- y
# hello world
# enter y for more calculation- sa

# %%
username="admin"
password="123"
def auth():
    x= input("enter username- ")
    y= input("enter password- ")
    if x!= username and y!=password:
        auth()
    else:
        print("you are logged in")
        
auth()
# Out:
# enter username- sauyran
# enter password- f324
# enter username- admin
# enter password- 123
# you are logged in

# %%
def signup():
    print("-------------please sign up------------")
    username= input("enter username- ")
    password= input("enter password- ")
    cpassword= input("enter cpassword- ")
    if password == cpassword:
        print("sign up sucessful")
        return username,password
    else:
        print("password and confirm password does not match")
        signup()
            
username,password= signup()
print(username,password)


def auth():
    print("---------sign in---------")
    x= input("enter username- ")
    y= input("enter password- ")
    if (x!= username) and (y!=password):
        print("invalid username or password")
        auth()
    else:
        print("you are logged in")
        
auth()
# Out:
# -------------please sign up------------
# enter username- admin
# enter password- admin123
# enter cpassword- admin123
# sign up sucessful
# admin admin123
# ---------sign in---------
# enter username- admin123
# enter password- 324
# invalid username or password
# ---------sign in---------
# enter username- admin123
# enter password- admin
# invalid username or password
# ---------sign in---------
# enter username- admin
# enter password- admin123
# you are logged in

# %%
import math as m
print(m.pi)
print(m.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import math as m
r= int(input("enter r= "))
a= m.pi*m.pow(r,2)
print(a)
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_4800/3757705333.py", line 2
#     r= int(input"enter r= ")
#                 ^
# SyntaxError: invalid syntax

# %%
print
